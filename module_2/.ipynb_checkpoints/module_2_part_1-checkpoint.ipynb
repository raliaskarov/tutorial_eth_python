# %% [markdown]
# # Task 1 - Vectors

# %%
import numpy as np
import csv
import matplotlib.pyplot as plt
import os

# %%
def describe_array(array):
    print(f"Type: {type(array)}")
    print(f"Data type: {array.dtype.name}")
    print(f"Size: {array.size}")
    print(f"Dimensions: {array.ndim}")

def show_stats(array):
    print("N=", np.size(array))
    print("Min=",np.min(array))
    print("Max=",np.max(array))
    print("Median=",np.median(array))
    print("Mean=",np.mean(array))
    print("Std=",np.std(array))

# %%
# --- Basic array Operations ---

# %%
ozone = np.array([11.8,17.2,34,61.5,64.2])
print(ozone)
# Out:
# [11.8 17.2 34.  61.5 64.2]

# %%
print(ozone[0])
# Out:
# 11.8

# %%
print(type(ozone))
# Out:
# <class 'numpy.ndarray'>

# %%
print(ozone.dtype.name)
# Out:
# float64

# %%
print(np.size(ozone))
# Out:
# 5

# %%
print(np.ndim(ozone))
# Out:
# 1

# %%
np.array([[11.8,17.2,34,61.5,64.2]],float)
# Out:
# array([[11.8, 17.2, 34. , 61.5, 64.2]])

# %%
x = np.array([[11.8,17.2,34,61.5,64.2]],float).T
print(x)
# Out:
# [[11.8]
#  [17.2]
#  [34. ]
#  [61.5]
#  [64.2]]

# %%
print(np.size(x))
# Out:
# 5

# %%
print(np.ndim(x))
# Out:
# 2

# %%
# --- Working with csv ---

# %%
# !cd module_2/
# Out:
# /bin/bash: line 1: cd: module_2/: No such file or directory

# %%
# !ls module_2
# Out:
# ls: cannot access 'module_2': No such file or directory

# %%
# test csv with 2 rows
try:
    with open("test.csv", 'r') as csvfile:
        data = list(csv.reader(csvfile, delimiter=","))
        print(f"data: {data}")
        print(type(data))
        test_array = np.array(data, float)
        test_array_T = np.array(data, float).T
        print(f"\ntest_array:\n{test_array}")
        describe_array(test_array)
        print(f"\ntest_array_t:\n{test_array_T}")
        describe_array(test_array_T)
except FileNotFoundError:
    pass
# Out:
# data: [['11.8', '17.2', '34', '61.5'], ['1.18', '1.72', '3.4', '6.15']]
# <class 'list'>
#
# test_array:
# [[11.8  17.2  34.   61.5 ]
#  [ 1.18  1.72  3.4   6.15]]
# Type: <class 'numpy.ndarray'>
# Data type: float64
# Size: 8
# Dimensions: 2
#
# test_array_t:
# [[11.8   1.18]
#  [17.2   1.72]
#  [34.    3.4 ]
#  [61.5   6.15]]
# Type: <class 'numpy.ndarray'>
# Data type: float64
# Size: 8
# Dimensions: 2

# %%
# !ls
# Out:
# cx_out		module_2_arrays.py  ozonzh2020.csv  test.csv
# module_2.ipynb	ozone_zh_2020.png   tempzh2020.csv

# %%
with open("ozonzh2020.csv", 'r') as csvfile:
    data = list(csv.reader(csvfile, delimiter=","))
ozone = np.array(data, float).T

# %%
describe_array(ozone)
# Out:
# Type: <class 'numpy.ndarray'>
# Data type: float64
# Size: 363
# Dimensions: 2

# %%
print(ozone)
# Out:
# [[ 11.8]
#  [ 17.2]
#  [ 34. ]
#  [ 61.5]
#  [ 64.2]
#  [ 22.6]
#  [ 45.5]
#  [ 18. ]
#  [ 41.8]
#  [ 76. ]
#  [ 49.9]
#  [ 39.8]
#  [ 36.1]
#  [ 60.8]
#  [ 79.9]
#  [ 51. ]
#  [ 63.8]
#  [ 67.3]
#  [ 65.4]
#  [ 58.6]
#  [ 34.4]
#  [  9.7]
#  [  9.5]
#  [ 10.9]
#  [  6.6]
#  [ 18.3]
#  [ 61.8]
#  [ 81.3]
#  [ 83.3]
#  [ 66.2]
#  [ 53. ]
#  [ 64.2]
#  [ 71.7]
#  [ 64.7]
#  [ 70.2]
#  [ 70.1]
#  [ 48.8]
#  [ 33.4]
#  [ 42.5]
#  [ 78.4]
#  [ 79.6]
#  [ 80.1]
#  [ 77.8]
#  [ 84.4]
#  [ 84.5]
#  [ 62.7]
#  [ 73.6]
#  [ 92.1]
#  [ 79.7]
#  [ 71.5]
#  [ 70.4]
#  [ 76.8]
#  [ 67.1]
#  [ 77.6]
#  [ 68.9]
#  [ 79.9]
#  [ 85.1]
#  [ 76.5]
#  [ 81.3]
#  [ 83.3]
#  [ 90. ]
#  [ 74. ]
#  [ 76.9]
#  [ 87.8]
#  [ 80.1]
#  [ 85.3]
#  [ 85.4]
#  [ 77. ]
#  [ 68.6]
#  [ 65.2]
#  [ 81.6]
#  [ 84.6]
#  [ 78.9]
#  [ 88.2]
#  [ 83.7]
#  [ 88.7]
#  [ 95.9]
#  [ 97.1]
#  [ 98.9]
#  [ 87.4]
#  [ 75.8]
#  [ 81.9]
#  [ 81.3]
#  [ 88.4]
#  [ 69.6]
#  [ 78.6]
#  [101.2]
#  [ 78.2]
#  [ 69. ]
#  [ 92.8]
# ...

# %%
print("N=", np.size(ozone))
print("Min=",np.min(ozone))
print("Max=",np.max(ozone))
print("Median=",np.median(ozone))
print("Mean=",np.mean(ozone))
print("Std=",np.std(ozone))
# Out:
# N= 363
# Min= 3.3
# Max= 166.5
# Median= 78.4
# Mean= 78.01046831955924
# Std= 34.848681167578206

# %%
# --- Plotting in Matplotlib ---

# %%
plt.plot(ozone)

# %%
# ensure file dir for out
os.makedirs("./cx_out", exist_ok=True)

# %%
fig, ax = plt.subplots(dpi=150)
ax.plot(ozone)
ax.set_title("Zurich barracks")
ax.set_ylabel("Ozone (O₃) [µg/m³]")
ax.set_xlabel("time [days]")
# savefig
plt.savefig("./cx_out/ozone_zh_2020.png")

# %%
# !ls
# Out:
# cx_out		module_2_arrays.py  ozonzh2020.csv  test.csv
# module_2.ipynb	ozone_zh_2020.png   tempzh2020.csv

# %%
# --- repeat for temperatures ---

# %%
# import temperature 
with open("tempzh2020.csv", "r") as file:
    data = list(csv.reader(file, delimiter = ","))
temp = data
temp = np.array(data, float).T
describe_array(temp)
show_stats(temp)
# Out:
# Type: <class 'numpy.ndarray'>
# Data type: float64
# Size: 366
# Dimensions: 2
# N= 366
# Min= -1.4
# Max= 28.4
# Median= 12.5
# Mean= 12.585245901639343
# Std= 7.206417966799454

# %%
type(data)
# Out:
# list

# %%
fig, ax = plt.subplots(figsize=(5,3), dpi=150)
ax.plot(temp)

# %%
# plot both

fig, (ax1, ax2) = plt.subplots(
    nrows=2, ncols=1,
    figsize=(6, 4),
    dpi=150,
    sharex=True
)
ax1.plot(temp,color="tab:red")
ax1.set_title("Temperature")
ax1.set_ylabel("C")

ax2.plot(ozone,color="tab:blue")
ax2.set_title("Ozone")
ax2.set_ylabel("mmg/m3")
ax2.set_xlabel("Day")

fig.tight_layout()
plt.show()

# %%
# --- Ssing Sublots ---

# %%
# same shart using statefil API
plt.subplot(211)
plt.plot(ozone)
plt.title("Zurich barracks")
plt.xlabel("time [days]")
plt.ylabel("Ozone (O₃) [µg/m³]")
plt.subplot(212)
plt.plot(temp)
plt.xlabel("time [days]")
plt.ylabel("temperature [°C]")
plt.tight_layout()
plt.savefig("./cx_out/ozone_temperature_zh_2020.png")

# %% [markdown]
# # Task 2 - Matrices

# %%
m = np.array([[1, 2, 3], [4, 5, 6]], int)
print(m)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
"""
You will develop a simple version of such a boss puzzle game in the next few lessons. The main thing is to learn how to create matrices and perform operations on them.

Our approach at a glance:

    Saving the game board in a matrix (lesson 12).
    Make a move (lesson 13).
    Perform several moves (lessons 14 to 16).
"""
# Out:
# '\nYou will develop a simple version of such a boss puzzle game in the next few lessons. The main thing is to learn how to create matrices and perform operations on them.\n\nOur approach at a glance:\n\n    Saving the game board in a matrix (lesson 12).\n    Make a move (lesson 13).\n    Perform several moves (lessons 14 to 16).\n'

# %%
import numpy as np
import matplotlib as plt
import os

# %%
m = np.array([['1','2'],['3','4']],str)
print(m)
# Out:
# [['1' '2']
#  ['3' '4']]

# %%
board = np.array([[3, 4, 8], [7, ' ', 5], [2, 1, 6]],str)
print(board)
# Out:
# [['3' '4' '8']
#  ['7' ' ' '5']
#  ['2' '1' '6']]

# %%
describe_array(board)
# Out:
# Type: <class 'numpy.ndarray'>
# Data type: str32
# Size: 9
# Dimensions: 2

# %%
print(np.shape(board))
# Out:
# (3, 3)

# %%
print(np.shape(board))
print(np.size(board)) 
#print(np.sum(board))
# Out:
# (3, 3)
# 9

# %%
import numpy as np
import matplotlib as plt
import os

# game
board = np.array([[3, 4, 8], [7, ' ', 5], [2, 1, 6]],str)
"""
target output
     C 1 2 3
   R  ------
   1 | 3 4 8 
   2 | 7 0 5 
   3 | 2 1 6 
"""
def output(v):
    print("  C 1 2 3")
    print("R  -------")
    for i in range (0,3):
        print(i+1, "|", end = " ")
        for j in range (0,3):
            print(v[i][j], end=" ")
        print()
def locate_value(matrix, value):
    v = str(value)
    coord  = np.where(matrix == v )
    i, j = coord[0][0], coord[1][0]
    return i, j
def adjacent(p, q):
    return abs(p[0]-q[0]) + abs(p[1]-q[1]) == 1

def board_game(board):


    # user selects tile to move 
    input_number_to_move = input('Number to move: ')
    
    # find coordinates
    coord_of_number_to_move = locate_value(board, input_number_to_move)
    coord_blank = locate_value(matrix=board, value=" ")
    
    # move
    if adjacent(coord_of_number_to_move, coord_blank):
        board[coord_blank] = board[coord_of_number_to_move]
        board[coord_of_number_to_move] = " "
    else:
        print("Only tiles adjacent to blank can be moved\n\n")
    
    # show board
    output(board)

# initial board
board = np.array([[3, 4, 8], [7, ' ', 5], [2, 1, 6]],str)

# display initial board
output(board)
attempts = 100

for i in range(attempts-1):
    board_game(board)
    print(f"Remaining steps: {(attempts-1-i)}")
# Out:
#   C 1 2 3
# R  -------
# 1 | 3 4 8
# 2 | 7   5
# 3 | 2 1 6
# Number to move:  4
#   C 1 2 3
# R  -------
# 1 | 3   8
# 2 | 7 4 5
# 3 | 2 1 6
# Remaining steps: 99
# Number to move:  3
#   C 1 2 3
# R  -------
# 1 |   3 8
# 2 | 7 4 5
# 3 | 2 1 6
# Remaining steps: 98
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[187], line 54
#      51 output(board)
#      53 for i in range(100):
# ---> 54     board_game(board)
#      55     print(f"Remaining steps: {(99-i)}")
#
# Cell In[187], line 31, in board_game(board)
#      27 def board_game(board):
#      28
#      29
#      30     # user selects tile to move
# ---> 31     input_number_to_move = input('Number to move: ')
#      33     # find coordinates
#      34     coord_of_number_to_move = locate_value(board, input_number_to_move)
#
# ...

# %%
# move 5 left
board[1][1] = board[1][2]
board[1][2] = ' '
output(board)
# Out:
#   C 1 2 3
# R  -------
# 1 | 3 4 8
# 2 | 7 5
# 3 | 2 1 6

# %%
def locate_value(matrix, value):
    v = str(value)
    coord  = np.where(matrix == v )
    i, j = coord[0][0], coord[1][0]
    return i, j
locate_value(matrix=board, value=" ")
# Out:
# (np.int64(1), np.int64(2))

# %%
def adjacent(p, q):
    return abs(p[0]-q[0]) + abs(p[1]-q[1]) == 1

# %%
output(board)
# Out:
#   C 1 2 3
# R  -------
# 1 | 3 4 8
# 2 | 7 6 5
# 3 | 2 1

# %%
x = locate_value(board, 6)
y = locate_value(board, " ")
adjacent(x, y)
# Out:
# np.False_

# %%
# --- find value in matrix ---

# %%
np.where(board == '2')
# Out:
# (array([2]), array([0]))

# %%
coord  = np.where(board == '2')
i, j = coord[0][0], coord[1][0]
board[i][j]
# Out:
# np.str_('2')

# %%
print(np.where(board == '2')[0])
print(np.where(board == '2')[1])
# Out:
# [2]
# [0]

# %%
board[2]
# Out:
# array(['2', '1', '6'], dtype='<U1')
