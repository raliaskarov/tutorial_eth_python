# %%
# independent part A

# %%
# Task
"""
Hotel
name: str
stars: int
floors: int
roomsPerFloor: int
occupancy: int
---------------------
printInfo(): none
getBookedRooms(): int
getMaxRooms(): int
checkin(): bool
checkout(): bool
"""

# %%
class Hotel:
    def __init__ (self, name, stars, floors, roomsPerFloor, occupancy):
        """
            name: The name of the hotel is stored here.
            stars: Here is the number of hotel stars.
            floors: This indicates how many floors the hotel has.
            roomsPerFloor: This indicates how many rooms are on a floor.
            occupancy: This attribute stores how many rooms are currently occupied
        """
        self.name = name
        self.stars = stars
        self.floors = floors
        self.roomsPerFloor = roomsPerFloor
        self.occupancy = occupancy

    def printInfo(self):
        """
            Shows hotel name, number of stars, number of rooms, number of occupied rooms
        """
        name = self.name
        stars = self.stars
        total_rooms = getMaxRooms(self.floors, self.roomsPerFloor)
        booked_rooms = getBookedRooms(roomsPerFloor=roomsPerFloor, floors=floors, occupancy=occupancy)
        print(f"Hotel: {name}\nTotal rooms: {total_rooms}\nBooked rooms: {booked_rooms}")

    def getMaxRooms(self, floors, roomsPerFloor):
        """
            Total rooms in the hotel
        """
        totalRooms = roomsPerFloor * floors
        return totalRooms
        
    def getBookedRooms(self, roomsPerFloor, floors, occupancy):
        """
            Description: How many rooms can be booked
            Input: floors, rooms per floor
            Output: number of bookable rooms 
        """
        totalRooms = getMaxRooms(floors, RoomsPerFloor)
        bookableRooms = totalRooms - occupancy
        return bookableRooms

    def checkin(self):
        """
            Increase occupancy by 1
        """
        currentOccupancy = self.occupancy
        self.occupancy += 1
        print(f"Occupancy changed from {currentOccupancy} to {self.occupancy}")

    def checkout(self):
        """
            Decrease occupancy by 1
        """
        currentOccupancy = self.occupancy
        self.occupancy -= 1
        print(f"Occupancy changed from {currentOccupancy} to {self.occupancy}")
    
    def copy(self):
        """
            Copy object
        """
        new_object = Hotel(self.name,
                           self.stars,
                           self.floors,
                           self.roomsPerFloor,
                           self.occupancy)

hotel_1 = Hotel(name = "Mariott",
                stars = 4,
                floors = 10,
                roomsPerFloor = 5,
                occupancy = 0)
hotel_1.printInfo()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 74
#      63         new_object = Hotel(self.name,
#      64                            self.stars,
#      65                            self.floors,
#      66                            self.roomsPerFloor,
#      67                            self.occupancy)
#      69 hotel_1 = Hotel(name = "Mariott",
#      70                 stars = 4,
#      71                 floors = 10,
#      72                 roomsPerFloor = 5,
#      73                 occupancy = 0)
# ---> 74 hotel_1.printInfo()
#
# Cell In[5], line 22, in Hotel.printInfo(self)
#      20 name = self.name
#      21 stars = self.stars
# ---> 22 total_rooms = getMaxRooms(self.floors, self.roomsPerFloor)
#      23 booked_rooms = getBookedRooms(roomsPerFloor=roomsPerFloor, floors=floors, occupancy=occupancy)
#      24 print(f"Hotel: {name}\nTotal rooms: {total_rooms}\nBooked rooms: {booked_rooms}")
#
# NameError: name 'getMaxRooms' is not defined
