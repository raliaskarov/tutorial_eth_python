# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import geopandas
import shapely
from shapely import box, LineString, normalize, Polygon, Point

## PART A: Initialize and analyse data
df = geopandas.read_file('./db_data/data.gpkg')
print(df)
print(df.head())
print(df.info())
cols_print_unique = ['sitzbankmodelle']
print("\n ===== UNIQUE VALUES: =====")
for c in cols_print_unique:
  print(f"{c}: {df[c].unique()}")
print("============================")



## PART B: Simple Filter
backrest = df[df["sitzbankmodelle"] == "mit Rückenlehne"]
print(backrest)

## PART C: Advanced Filter & Data Augmentation

eth = Point(2683756.785475, 1247981.202527)
x_eth = 2683756.785475
y_eth = 1247981.202527

# filter benches north of ETH
northern = df[df["geometry"].y > 1247981]
print(northern) # This print-statement is optional

# compute distance
dist = []
dt = shapely.distance(northern["geometry"], eth)
idx = dt.index
for i in idx:
  dist.append(dt[i].item())
  
# add to df
northern["Distance to ETH"] = dist
print(northern)

# calculate percentage
frac = northern.shape[0]/df.shape[0]
print("Percentage of Benches north of ETH: "+str(np.round(frac*100, 2))+"%")

## PART D: Plotting
# plot ZH 
mapZH = geopandas.read_file('./maps/zhkreise.shp')
mapZH.crs = "EPSG:2056" ## 4326: Geocode for ZH, 2056: Geocode for CH
### ======== Complete the code to create/save an image ==========
ax = mapZH.plot()
plt.axis('off')
plt.savefig('./cx_out/basemap.png')

## Step 1: Plot all benches in Zurich
#mapZH = geopandas.read_file('./maps/stadtzh.shp')
benches = geopandas.GeoSeries(df["geometry"], crs="EPSG:2056")
benches = benches.to_crs(mapZH.crs)
benches.plot(ax=ax, color="lime", markersize=6)
plt.savefig('./cx_out/stadtZH.png')

# overlay northern
map_north = geopandas.GeoSeries(northern["geometry"], crs="EPSG:2056")
map_north = map_north.to_crs(mapZH.crs)
map_north.plot(ax=ax, color="red", marker="*", markersize=1)
plt.savefig('./cx_out/combi.png')

### =============================================================


## Step 2: Combine all benches north of ETH and all city benches
##         in one image
#bigmap = mapZH.plot()
#northern.plot(ax=???, marker=???, color=???, markersize=???)
### ======== Complete the code to create/save an image ==========


### =============================================================
# Out:
#      objid   sitzbankmodelle                adresse  \
# 0      147   mit Rückenlehne       Algierstrasse 49
# 1      175   mit Rückenlehne     Friedhofstrasse 73
# 2      212   mit Rückenlehne  Bachwiesenstrasse 145
# 3      285   mit Rückenlehne     Friedhofstrasse 87
# 4      365   mit Rückenlehne   Untermoosstrasse 36a
# ...    ...               ...                    ...
# 7192  8495   mit Rückenlehne             Zeltweg 83
# 7193  8543   mit Rückenlehne     Klosbachstrasse 19
# 7194  8878   mit Rückenlehne      Eidmattstrasse 43
# 7195  8966   mit Rückenlehne        Arterstrasse 25
# 7196  9006  ohne Rückenlehne      Streulistrasse 76
#
#                              geometry
# 0      POINT (2678694.14 1248127.555)
# 1     POINT (2678330.805 1248506.981)
# 2     POINT (2678997.455 1247729.104)
# 3     POINT (2678382.085 1248298.005)
# 4       POINT (2678760.188 1248164.9)
# ...                               ...
# 7192   POINT (2684280.708 1246755.15)
# 7193  POINT (2684322.111 1246719.484)
# 7194  POINT (2684726.454 1246651.374)
# 7195  POINT (2684354.838 1246843.345)
# 7196  POINT (2685094.091 1246427.167)
#
# [7197 rows x 4 columns]
#   objid  sitzbankmodelle                adresse  \
# 0   147  mit Rückenlehne       Algierstrasse 49
# 1   175  mit Rückenlehne     Friedhofstrasse 73
# 2   212  mit Rückenlehne  Bachwiesenstrasse 145
# 3   285  mit Rückenlehne     Friedhofstrasse 87
# 4   365  mit Rückenlehne   Untermoosstrasse 36a
#
#                           geometry
# 0   POINT (2678694.14 1248127.555)
# 1  POINT (2678330.805 1248506.981)
# 2  POINT (2678997.455 1247729.104)
# 3  POINT (2678382.085 1248298.005)
# 4    POINT (2678760.188 1248164.9)
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 7197 entries, 0 to 7196
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   objid            7197 non-null   object
#  1   sitzbankmodelle  7197 non-null   object
#  2   adresse          7197 non-null   object
#  3   geometry         7197 non-null   geometry
# dtypes: geometry(1), object(3)
# memory usage: 225.0+ KB
# None
#
#  ===== UNIQUE VALUES: =====
# sitzbankmodelle: ['mit Rückenlehne' 'ohne Rückenlehne' 'Tisch-Bank-Kombination' 'Tisch'
#  'mit Rückenlehne und 2 Armlehnen' 'Sonstige' 'Wandmontage'
#  'auf Sockel aufgeschraubt' '046 / normalen Sitzlatten'
#  'mit Rückenlehne und Armlehne links'
#  'mit Rückenlehne und Armlehne rechts' '046 / gebogene Sitzlatten' ''
#  '046 / trapez Sitzlatten']
# ============================
#      objid  sitzbankmodelle                adresse  \
# 0      147  mit Rückenlehne       Algierstrasse 49
# 1      175  mit Rückenlehne     Friedhofstrasse 73
# 2      212  mit Rückenlehne  Bachwiesenstrasse 145
# 3      285  mit Rückenlehne     Friedhofstrasse 87
# 4      365  mit Rückenlehne   Untermoosstrasse 36a
# ...    ...              ...                    ...
# 7191  8480  mit Rückenlehne    Steinwiesstrasse 26
# 7192  8495  mit Rückenlehne             Zeltweg 83
# 7193  8543  mit Rückenlehne     Klosbachstrasse 19
# 7194  8878  mit Rückenlehne      Eidmattstrasse 43
# 7195  8966  mit Rückenlehne        Arterstrasse 25
#
#                              geometry
# 0      POINT (2678694.14 1248127.555)
# 1     POINT (2678330.805 1248506.981)
# 2     POINT (2678997.455 1247729.104)
# 3     POINT (2678382.085 1248298.005)
# 4       POINT (2678760.188 1248164.9)
# ...                               ...
# 7191  POINT (2684110.883 1247172.638)
# 7192   POINT (2684280.708 1246755.15)
# 7193  POINT (2684322.111 1246719.484)
# 7194  POINT (2684726.454 1246651.374)
# 7195  POINT (2684354.838 1246843.345)
#
# [5131 rows x 4 columns]
#      objid   sitzbankmodelle                adresse  \
# 0      147   mit Rückenlehne       Algierstrasse 49
# 1      175   mit Rückenlehne     Friedhofstrasse 73
# 3      285   mit Rückenlehne     Friedhofstrasse 87
# 4      365   mit Rückenlehne   Untermoosstrasse 36a
# 5      395   mit Rückenlehne  Altstetterstrasse 290
# ...    ...               ...                    ...
# 6791  6873  ohne Rückenlehne       Bullingerplatz 3
# 6793  7172   mit Rückenlehne       Bullingerplatz 3
# 6794  7248   mit Rückenlehne       Bullingerplatz 3
# 6799  8166  ohne Rückenlehne    Sihlfeldstrasse 141
# 6801  8576   mit Rückenlehne    Sihlfeldstrasse 150
#
#                              geometry
# 0      POINT (2678694.14 1248127.555)
# 1     POINT (2678330.805 1248506.981)
# 3     POINT (2678382.085 1248298.005)
# 4       POINT (2678760.188 1248164.9)
# 5     POINT (2678873.993 1248018.391)
# ...                               ...
# 6791  POINT (2681357.168 1248178.613)
# 6793  POINT (2681358.751 1248175.346)
# 6794  POINT (2681378.945 1248176.285)
# 6799  POINT (2681351.618 1248180.829)
# 6801  POINT (2681367.657 1248225.405)
#
# [3536 rows x 4 columns]
#      objid   sitzbankmodelle                adresse  \
# 0      147   mit Rückenlehne       Algierstrasse 49
# 1      175   mit Rückenlehne     Friedhofstrasse 73
# 3      285   mit Rückenlehne     Friedhofstrasse 87
# 4      365   mit Rückenlehne   Untermoosstrasse 36a
# 5      395   mit Rückenlehne  Altstetterstrasse 290
# ...    ...               ...                    ...
# 6791  6873  ohne Rückenlehne       Bullingerplatz 3
# 6793  7172   mit Rückenlehne       Bullingerplatz 3
# 6794  7248   mit Rückenlehne       Bullingerplatz 3
# 6799  8166  ohne Rückenlehne    Sihlfeldstrasse 141
# 6801  8576   mit Rückenlehne    Sihlfeldstrasse 150
#
#                              geometry  Distance to ETH
# 0      POINT (2678694.14 1248127.555)      5064.760434
# 1     POINT (2678330.805 1248506.981)      5451.394970
# 3     POINT (2678382.085 1248298.005)      5384.029068
# 4       POINT (2678760.188 1248164.9)      4999.973109
# 5     POINT (2678873.993 1248018.391)      4882.934091
# ...                               ...              ...
# 6791  POINT (2681357.168 1248178.613)      2407.724013
# 6793  POINT (2681358.751 1248175.346)      2405.880511
# 6794  POINT (2681378.945 1248176.285)      2385.829519
# 6799  POINT (2681351.618 1248180.829)      2413.437654
# 6801  POINT (2681367.657 1248225.405)      2401.576507
#
# [3536 rows x 5 columns]
# Percentage of Benches north of ETH: 49.13%
# /home/ralia/.venvs/data/lib/python3.13/site-packages/geopandas/geodataframe.py:1968: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
