# %% [markdown]
# # HTTP Requests

# %%
import requests
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import requests
#
# ModuleNotFoundError: No module named 'requests'
